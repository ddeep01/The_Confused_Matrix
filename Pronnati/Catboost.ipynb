# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import GroupShuffleSplit, GridSearchCV, GroupKFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from catboost import CatBoostRegressor

# %% [markdown]
# ## Data Loading

# %%
df = pd.read_csv("youtube_final_csv.csv")

# %%
df.head()
# Out:
#       video_id                                              title  topic  \
# 0  0BkEej0H1VU  *SMALL* Apartment Makeover w/ Surprise REVEAL!...  Hobby
# 1  nL6DN0CWRWI  transforming my apartment 🏡🌷 i got a new couch...  Hobby
# 2  gAgAYyo1O0o  Scandi-Style Studio Apartment Makeover With Po...  Hobby
# 3  3EJu45Tkbyc  *196 sq ft* Organic Modern Studio Apartment Ma...  Hobby
# 4  cShkxcg_la0  Small APARTMENT MAKEOVER 2024 :: Budget AirBnB...  Hobby
#
#    category_id          published_at  duration_seconds video_definition  \
# 0           22  2025-05-15T20:50:21Z              1493               hd
# 1           26  2024-05-26T17:00:34Z              1508               hd
# 2           26  2025-10-25T15:01:20Z              1798               hd
# 3           26  2025-09-20T15:00:07Z              1821               hd
# 4           26  2024-03-18T17:00:31Z              2203               hd
#
#    captions_flag                channel_id    channel_title  subscriber_count  \
# 0          False  UCtwzsvzRCfPddq2gPlgKW1w         Lone Fox           1770000
# 1          False  UCFGQGLGZU1TgX-PhawwxjJg    annika's leaf           1070000
# 2           True  UCrh9tOpAY2-Ev5pRssXq2Wg  Alexandra Gater            888000
# 3           True  UCrh9tOpAY2-Ev5pRssXq2Wg  Alexandra Gater            888000
# 4          False  UCbQj1aJiioDM8g0tmGmtC_w  This Crazy Life            457000
#
#    total_videos  channel_age_days   views  likes  comments
# 0           485              2810  312359  19516       949
# 1           308              3314  353355  14823       727
# 2           422              4020  350306  26864      1018
# 3           422              4020  458367  33976      1458
# 4           787              3009  490393  17309      1610

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50160 entries, 0 to 50159
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   video_id          50160 non-null  object
#  1   title             50160 non-null  object
#  2   topic             50160 non-null  object
#  3   category_id       50160 non-null  int64
#  4   published_at      50160 non-null  object
#  5   duration_seconds  50160 non-null  int64
#  6   video_definition  50160 non-null  object
#  7   captions_flag     50160 non-null  bool
#  8   channel_id        50160 non-null  object
#  9   channel_title     50160 non-null  object
#  10  subscriber_count  50160 non-null  int64
#  11  total_videos      50160 non-null  int64
#  12  channel_age_days  50160 non-null  int64
#  13  views             50160 non-null  int64
#  14  likes             50160 non-null  int64
#  15  comments          50160 non-null  int64
# dtypes: bool(1), int64(8), object(7)
# memory usage: 5.8+ MB

# %%
df.describe()
# Out:
#         category_id  duration_seconds  subscriber_count   total_videos  \
# count  50160.000000      50160.000000      5.016000e+04   50160.000000
# mean      22.571531       2422.810825      2.977674e+06    5172.923405
# std        6.164992       6201.971156      1.061033e+07   28809.301109
# min        1.000000        240.000000      0.000000e+00       1.000000
# 25%       22.000000        630.000000      5.350000e+04     213.000000
# 50%       24.000000       1199.000000      3.230000e+05     565.000000
# 75%       27.000000       1990.000000      1.580000e+06    1505.000000
# max       29.000000     367231.000000      4.500000e+08  643411.000000
#
#        channel_age_days         views         likes       comments
# count      50160.000000  5.016000e+04  5.016000e+04   50160.000000
# mean        3236.794597  2.709607e+06  3.010090e+04    1119.361643
# std         1826.909349  3.278482e+07  1.861561e+05    6548.073127
# min            3.000000  1.000000e+03  0.000000e+00       0.000000
# 25%         1809.000000  2.033125e+04  4.250000e+02      29.000000
# 50%         3121.000000  1.385370e+05  2.630000e+03     141.000000
# 75%         4581.000000  8.132555e+05  1.387225e+04     596.000000
# max         7446.000000  3.580474e+09  1.299725e+07  550394.000000

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum()
# Out:
# video_id            0
# title               0
# topic               0
# category_id         0
# published_at        0
# duration_seconds    0
# video_definition    0
# captions_flag       0
# channel_id          0
# channel_title       0
# subscriber_count    0
# total_videos        0
# channel_age_days    0
# views               0
# likes               0
# comments            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(90)

# %%
# Drop duplicates
df = df.drop_duplicates(subset=['video_id'])

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Basic Filters
df = df[df['views'] > 0]
df = df[df['likes'] <= df['views']]

# %% [markdown]
# ## Feature Engineering

# %%
# Computing target variable (Engagement Rate)
df['engagement_rate'] = (np.log1p(df['likes']) + np.log1p(df['comments'])) / np.log1p(df['views'])

# %%
# Datetime conversion
df['published_at'] = pd.to_datetime(df['published_at'], errors='coerce')

df['publish_hour'] = df['published_at'].dt.hour
df['publish_dayofweek'] = df['published_at'].dt.dayofweek

df['publish_hour_sin'] = np.sin(2*np.pi*df['publish_hour']/24)
df['publish_hour_cos'] = np.cos(2*np.pi*df['publish_hour']/24)
df['publish_dow_sin'] = np.sin(2*np.pi*df['publish_dayofweek']/7)
df['publish_dow_cos'] = np.cos(2*np.pi*df['publish_dayofweek']/7)

# %%
# Categorical conversions
df['category_id'] = df['category_id'].astype(str)
df['video_definition'] = df['video_definition'].astype(str)
df['captions_flag'] = df['captions_flag'].astype(str)

# %%
# Convert Duration in seconds to minutes
df['duration_seconds'] = df['duration_seconds'].clip(5, 7200)
df['duration_minutes'] = df['duration_seconds'] / 60

# %%
# Resolving noisiness of subscriber count by Log-Transformation
df['subscriber_count_log'] = np.log1p(df['subscriber_count'])

# Additinal Features
df['title_length'] = df['title'].fillna("").str.len()
df['title_words'] = df['title'].fillna("").str.split().str.len()
df['title_exclamation'] = df['title'].fillna("").str.count('!')
df['title_question'] = df['title'].fillna("").str.count(r'\?')

df['is_hd'] = (df['video_definition'] == "hd").astype(int)

# %%
# Drop uneccessary/ leaky columns
drop_cols = [
    'video_id', 'topic', 'title', 'published_at', 'channel_title',
    'duration_seconds', 'views', 'likes', 'comments', 'subscriber_count',
    'publish_hour', 'publish_dayofweek','video_definition'
]
df.drop(columns=drop_cols, inplace=True, errors="ignore")

# %%
# Group Train-Test Split
target = 'engagement_rate'
categorical_features = ['category_id', 'captions_flag']

numeric_features = [
    'total_videos','channel_age_days','title_length','title_words',
    'title_exclamation','title_question',
    'duration_minutes','publish_hour_sin','publish_hour_cos',
    'publish_dow_sin','publish_dow_cos',
    'subscriber_count_log','is_hd'
]

all_features = categorical_features + numeric_features

X = df[all_features].copy()
y = df[target].copy()

groups = df['channel_id']

gss = GroupShuffleSplit(test_size=0.2, n_splits=1, random_state=42)
train_idx, test_idx = next(gss.split(X, y, groups))

X_train, X_test = X.iloc[train_idx].copy(), X.iloc[test_idx].copy()
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

groups_train = groups.iloc[train_idx].copy()

train_means = y_train.groupby(X_train['category_id']).mean()
X_train['category_te'] = X_train['category_id'].map(train_means)
X_test['category_te']  = X_test['category_id'].map(train_means)
numeric_features.append('category_te')

# %%
# Clipping
def robust_clip(train_col, test_col):
    q_low = train_col.quantile(0.01)
    q_high = train_col.quantile(0.99)
    
    Q1, Q3 = train_col.quantile(0.25), train_col.quantile(0.75)
    IQR = Q3 - Q1
    
    lower = max(q_low, Q1 - 1.5*IQR)
    upper = min(q_high, Q3 + 1.5*IQR)
    
    return train_col.clip(lower, upper), test_col.clip(lower, upper)

for col in ['total_videos', 'channel_age_days']:
    X_train[col], X_test[col] = robust_clip(X_train[col], X_test[col])

# %% [markdown]
# ## Model Training

# %%
# Train Catboost
base_model = CatBoostRegressor(
    loss_function='RMSE',
    cat_features=categorical_features,
    random_seed=42,
    verbose=0
)

param_grid = {
    "depth": [4, 6],
    "learning_rate": [0.02, 0.03, 0.05],
    "iterations": [1200, 2000],
    "l2_leaf_reg": [5, 20],
    "subsample": [0.7, 0.9]
}

# GroupKFold for grouped cross-validation
group_cv = GroupKFold(n_splits=3)

grid = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid,
    scoring="neg_root_mean_squared_error",
    cv=group_cv,
    verbose=2,
    n_jobs=-1
)

grid.fit(X_train, y_train, groups=groups_train)

# Train final model using Best Parameters
print("\n BEST PARAMS FROM GRID SEARCH ")
print(grid.best_params_)

best_params = grid.best_params_

model = CatBoostRegressor(
    **best_params,
    loss_function='RMSE',
    cat_features=categorical_features,
    random_seed=42,
    early_stopping_rounds=150,
    verbose=200
)

model.fit(
    X_train, y_train,
    eval_set=(X_test, y_test)
)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time=  21.7s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time=  21.8s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time=  21.9s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time=  23.0s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time=  22.1s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time=  22.3s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time=  21.4s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time=  22.7s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time=  22.3s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time=  23.3s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time=  23.1s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time=  23.0s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time=  29.9s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time=  29.3s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time=  29.3s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  30.2s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  34.4s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  35.6s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  35.7s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  34.7s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  33.5s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  33.7s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  34.6s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  35.5s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  31.3s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  32.0s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  31.5s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  35.2s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  32.6s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  31.4s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  31.7s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  34.2s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  40.5s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  41.2s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  42.0s
# [CV] END depth=4, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  36.8s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time=  42.2s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time=  41.2s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time=  41.1s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time=  44.3s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time=  51.8s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time=  51.2s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time=  52.0s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time=  49.5s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time=  52.8s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time=  55.0s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time=  54.5s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time=  54.6s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time=  42.4s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time=  40.7s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time=  41.6s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  43.7s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  41.9s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  40.2s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  44.3s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  42.6s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  42.2s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  43.5s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  40.9s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  38.0s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  36.4s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  35.0s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  36.0s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  37.6s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  38.0s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  37.5s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  38.1s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  37.7s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  44.2s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  47.1s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  46.8s
# [CV] END depth=4, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  48.1s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time=  37.4s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time=  35.3s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time=  35.8s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time=  35.3s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time=  40.8s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time=  39.5s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time=  40.7s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time=  40.0s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time=  42.1s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time=  43.8s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time=  44.4s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time=  45.5s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time=  38.2s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time=  37.6s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time=  37.8s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  38.3s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  43.2s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  40.9s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  43.3s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  40.3s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  34.7s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  39.2s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  38.6s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  35.7s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  36.3s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  35.4s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  34.6s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  37.3s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  39.1s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  35.9s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  37.4s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  36.6s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  33.3s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  35.3s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  34.5s
# [CV] END depth=6, iterations=1200, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  33.2s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time= 1.2min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time= 1.2min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.7; total time= 1.2min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time= 1.3min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time= 1.3min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.02, subsample=0.9; total time= 1.3min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time= 1.3min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time= 1.2min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.7; total time= 1.4min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time= 1.5min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time= 1.5min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, subsample=0.9; total time= 1.5min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time= 1.0min
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time=  54.1s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.7; total time=  53.8s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  54.5s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  59.4s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  55.5s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, subsample=0.9; total time=  60.0s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  56.0s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.7; total time=  53.6s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  56.8s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  52.4s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.02, subsample=0.9; total time=  56.6s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  54.3s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  53.5s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.7; total time=  53.0s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  55.7s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  54.6s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.03, subsample=0.9; total time=  52.7s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  53.8s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  53.2s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.7; total time=  53.4s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  54.6s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  53.3s
# [CV] END depth=6, iterations=2000, l2_leaf_reg=20, learning_rate=0.05, subsample=0.9; total time=  50.1s
#
#  BEST PARAMS FROM GRID SEARCH
# {'depth': 6, 'iterations': 1200, 'l2_leaf_reg': 5, 'learning_rate': 0.02, 'subsample': 0.7}
# 0:	learn: 0.2422361	test: 0.2450497	best: 0.2450497 (0)	total: 25.1ms	remaining: 30.2s
# 200:	learn: 0.2027034	test: 0.2136400	best: 0.2136400 (200)	total: 2.74s	remaining: 13.6s
# 400:	learn: 0.1963411	test: 0.2111238	best: 0.2111238 (400)	total: 5.33s	remaining: 10.6s
# 600:	learn: 0.1928721	test: 0.2100916	best: 0.2100733 (599)	total: 7.84s	remaining: 7.81s
# 800:	learn: 0.1896380	test: 0.2093874	best: 0.2093870 (794)	total: 10.3s	remaining: 5.14s
# 1000:	learn: 0.1869477	test: 0.2088591	best: 0.2088467 (995)	total: 12.9s	remaining: 2.57s
# 1199:	learn: 0.1848039	test: 0.2082305	best: 0.2082304 (1195)	total: 15.5s	remaining: 0us
#
# bestTest = 0.2082304121
# bestIteration = 1195
#
# Shrink model to first 1196 iterations.

# %%
# Evaluation
y_pred = model.predict(X_test)

print("\n TEST PERFORMANCE ")
print("Test MAE:", mean_absolute_error(y_test, y_pred))
print("Test RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("Test R2:", r2_score(y_test, y_pred))

y_train_pred = model.predict(X_train)
print("\n TRAIN PERFORMANCE ")
print("Train RMSE:", np.sqrt(mean_squared_error(y_train, y_train_pred)))
print("Train MAE:", mean_absolute_error(y_train, y_train_pred))
print("Train R2:", r2_score(y_train, y_train_pred))
# Out:
#  TEST PERFORMANCE
# Test MAE: 0.15204589042670164
# Test RMSE: 0.20823041251799765
# Test R2: 0.28300364071088824
#
#  TRAIN PERFORMANCE
# Train RMSE: 0.18483668126343047
# Train MAE: 0.13370693441005715
# Train R2: 0.4220652859186843

# %% [markdown]
# ## Save the Model

# %%
import joblib
joblib.dump(model, "Catboost_final.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!
